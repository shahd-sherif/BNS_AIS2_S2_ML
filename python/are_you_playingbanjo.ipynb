# %%
print("are you playing banjo?")
x=input("What is your name? ")
if x[0].lower() == "r":
    print(x + " plays banjo")
else:
    print(x + " does not play banjo")
# Out:
# are you playing banjo?
# shahd does not play banjo
