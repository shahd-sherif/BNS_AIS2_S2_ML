# %%
x="###!!@mocleW EPGTQ!!!6789"
print(x[6:18:1])
# Out:
# mocleW EPGTQ

# %%
print(x[-14:-20:-1])
# Out:
# Welcom

# %%
if (x.find("E")!=-1):
    print(x.replace("E",""))
# Out:
# ###!!@mocleW PGTQ!!!6789
