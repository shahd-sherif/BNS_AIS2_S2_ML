# %%
x=input()
if (x.find("@")!=-10):
    print("Invalid email")
if (x.find(".")!=-4):
    print("Invalid email")
print("Valid email")

print(x[0:-10])
print(x[-4:-10:1])
if(x.find(".com")!=-1):
    print("commertial domain")
elif (x.find(".edu")!=-1):
    print("educational domain")
else:
    print("other domain")
# Out:
# Invalid email
# Invalid email
# Valid email
# Amit_ml
#
# educational domain
