# %%
x=input(str("write a word: "))
word=x.split()
word=x.reverse()
print(word)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 x=input(str("write a word: "))
#       2 word=x.split()
# ----> 3 word=x.reverse()
#       4 print(word)
#
# AttributeError: 'str' object has no attribute 'reverse'
