# %%
x="&&&**$gnirtS PLIO!!@1234 "
print(x[6:17:1])
# Out:
# gnirtS PLIO

# %%
print(x[-13:-20:-1])
# Out:
#  String

# %%
if (x.find("I")!=-1 and x.find("O")!=-1):
    print(x.replace("I","E").replace("O","U"))
# Out:
# &&&**$gnirtS PLEU!!@1234
