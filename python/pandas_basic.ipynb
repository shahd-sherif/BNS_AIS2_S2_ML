# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.5 MB 670.4 kB/s eta 0:00:18
#    - -------------------------------------- 0.5/12.5 MB 670.4 kB/s eta 0:00:18
#    -- ------------------------------------- 0.8/12.5 MB 644.9 kB/s eta 0:00:19
#    --- ------------------------------------ 1.0/12.5 MB 653.7 kB/s eta 0:00:18
#    --- ------------------------------------ 1.0/12.5 MB 653.7 kB/s eta 0:00:18
#    --- ------------------------------------ 1.0/12.5 MB 653.7 kB/s eta 0:00:18
#    ---- ----------------------------------- 1.3/12.5 MB 639.0 kB/s eta 0:00:18
# ...

# %%
import numpy as np
def ml_init(shape, value=2):
    return np.full(shape,value)

# %%
ml_init((3,3))
# Out:
# array([[2, 2, 2],
#        [2, 2, 2],
#        [2, 2, 2]])

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 1.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.8 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.8 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.8 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.8 MB 2.2 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.8 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 3.9/9.8 MB 2.4 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.8 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 5.2/9.8 MB 2.6 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
s= pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data=[[1.22,"abc"],
      [2.22,"def"],
      [3.22,"ghi"],
      [4.22,"jkl"],]
df=pd.DataFrame(data,columns=["num","string"])
type(data)
# Out:
# list

# %%
df
# Out:
#     num string
# 0  1.22    abc
# 1  2.22    def
# 2  3.22    ghi
# 3  4.22    jkl

# %%
df.columns
# Out:
# Index(['num', 'string'], dtype='str')

# %%
display(df)
# Out:
#     num string
# 0  1.22    abc
# 1  2.22    def
# 2  3.22    ghi
# 3  4.22    jkl

# %%
df.columns=("one","two")

# %%
df
# Out:
#     one  two
# 0  1.22  abc
# 1  2.22  def
# 2  3.22  ghi
# 3  4.22  jkl

# %%
df.index=("r1","r2","r3","r4")

# %%
df
# Out:
#      one  two
# r1  1.22  abc
# r2  2.22  def
# r3  3.22  ghi
# r4  4.22  jkl

# %%
df.dtypes
# Out:
# one    float64
# two        str
# dtype: object

# %%
df["one"].dtype
# Out:
# dtype('float64')

# %%
df=df.astype({"one":np.float64,"two":str})

# %%
df.dtypes
# Out:
# one    float64
# two        str
# dtype: object

# %%
df["one"].max()
# Out:
# np.float64(4.22)

# %%
def range(df):
    return df.one.max()-df.one.min()

# %%
range(df)
# Out:
# np.float64(3.0)

# %%
df.one.value_counts()
# Out:
# one
# 1.22    1
# 2.22    1
# 3.22    1
# 4.22    1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, r1 to r4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     4 non-null      float64
#  1   two     4 non-null      str
# dtypes: float64(1), str(1)
# memory usage: 268.0+ bytes

# %%
x=df.one.values
type(x)
# Out:
# numpy.ndarray

# %%
df.values
# Out:
# array([[1.22, 'abc'],
#        [2.22, 'def'],
#        [3.22, 'ghi'],
#        [4.22, 'jkl']], dtype=object)

# %%
df.replace("abc","shahd")
# Out:
#      one    two
# r1  1.22  shahd
# r2  2.22    def
# r3  3.22    ghi
# r4  4.22    jkl
