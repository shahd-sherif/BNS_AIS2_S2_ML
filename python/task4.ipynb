# %%
x="##$$$@!yalpstcejorp EPUVT****9887"
print(x[7:25:1])
# Out:
# yalpstcejorp EPUVT

# %%
print(x[-15:-27:-1])
# Out:
# projectsplay

# %%
if(x.find("E")!=-1 and x.find("U")!=-1):
    print(x.replace("E","A").replace("U","O"))
# Out:
# ##$$$@!yalpstcejorp APOVT****9887
